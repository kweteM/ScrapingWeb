# %% [markdown]
# <h1 style='color:blue' align='center'>Scraping Cars' website</h1>

# %% [markdown]
# ### Scraping from four differenrt links of a website:
# - first link contains cars' prices in 2023.
# - second link contains cars' prices in 2022.
# - third link contains cars' prices in 2021.
# - fourth link contains cars' prices in 2020.

# %% [markdown]
# ### Details:
# - cars' names.
# - years.
# - prices (in Kenya shilling).

# %% [markdown]
# ### Problem Statement:
# - extract the details of all the cars from all the four links and import all the details to a single csv file.

# %% [markdown]
# #### 1. Importing Dependencies

# %%
# Importing all needed libraries

from bs4 import BeautifulSoup
import requests
from csv import writer
import pandas as pd

# %% [markdown]
# #### 2. Web Scraping

# %% [markdown]
# #### 2. a. Accessing the website, extracting data, importing to csv file (First Link)

# %%
source = requests.get('https://www.ccarprice.com/ke/2023-model-car-price-in-Kenya-86.php') # requesting access

soup = BeautifulSoup(source.text,'html.parser') # pearsing the html page

# creating csv file
with open('cars_prices.csv', 'w', newline='', encoding='utf-8') as f:
    thewriter = writer(f)
    header = ['name', 'price']
    thewriter.writerow(header)
    
    cars = soup.find_all('div', class_='listing') # finding all the div tag which has a class named listing
    
    # looping through all the div tags with a class named listing, and extracting needed cars' details 
    for car in cars:                               
        name = car.strong.text.strip('[]')[:-4] # extracting the text without the date and any square bracket
        price = car.text.split()[-1] # extracting the text without first string
        print(name, price)
        
        # setting columns' names
        carsinfo = [name, price]
        thewriter.writerow(carsinfo)
# Out:
# Audi S1 Hoonitron  1,059,736,000
# Bugatti W16 Mistral  695,000,000
# Bugatti Chiron Super Sport 300 Plus  542,100,000
# Lamborghini Sian Roadster  542,100,000
# Bugatti Chiron Super Sport  535,150,000
# Hennessey Venom F5 Roadster  417,000,000
# Hennessey Venom F5  403,100,000
# Rimac Nevera  347,500,000
# Ferrari Daytona SP3  326,650,000
# Bentley Batur  271,050,000
# BMW 3.0 CSL Coupe  104,250,000
# BMW 3.0 CSL  104,250,000
# Audi PB18 E-Tron Concept  103,972,000
# Lamborghini Aventador SVJ Roadster  79,780,440
# Toyota Land Cruiser ZX Gasoline 3.5L  74,577,670
# Lamborghini Aventador SVR Track-Only Edition  66,720,000
# Rolls Royce Wraith  65,288,300
# Rolls Royce Phantom  64,635,000
# Rolls Royce Dawn  60,888,950
# Ferrari 296 GTS  55,600,000
# Rolls Royce Spectre  55,600,000
# Ferrari 296 GTB  48,844,600
# BMW i7 M70 xDrive  48,650,000
# Rolls Royce Cullinan  48,441,500
# Rolls Royce Ghost  47,468,500
# Bentley Continental GT Speed Convertible  44,104,700
# BMW M8 Coupe Competition  42,824,510
# Lamborghini Huracan Evo  40,476,800
# Bentley Continental GT Speed  40,101,500
# Lamborghini Urus Performante  36,233,130
# Bentley Continental GT V8 Convertible  36,028,800
# Lamborghini Urus  35,862,000
# Nissan GT-R NISMO  34,852,860
# Lamborghini Huracan Tecnica  33,221,000
# Bentley Bentayga  32,929,100
# Audi A8L Technology  32,923,540
# Audi R8 Coupe V10 GT RWD  31,990,850
# Lamborghini Urus S  31,970,000
# Nissan Z GT4  31,831,000
# Audi R8 V10 GT RWD  31,275,000
# Audi R8 Spyder 5.2 V10 performance quattro  30,871,900
# Audi R8  30,871,900
# Audi R8 Spyder RWD  30,871,900
# Audi R8 Coupe  30,858,000
# Aston Martin DB11 V8 Coupe  30,163,000
# Bentley Flying Spur Hybrid  29,857,200
# Nissan Z GT4 Nismo  29,315,100
# Audi R8 Coupe 5.2 V10 performance quattro  29,148,300
# Bentley Bentayga Hybrid  27,424,700
# Audi A8L Celebration  27,309,330
# BMW X6 M50d  26,151,460
# Toyota GR Supra GT4 EVO  25,854,000
# BMW XM Label Red  25,715,000
# BMW M3 CS Sedan  25,089,500
# Audi RS E-Tron GT Special Edition  25,006,100
# BMW X7 xDrive40d M Sport  25,004,710
# Audi R8 Spyder V10 Performance  24,156,810
# BMW X7 xDrive40i M Sport  23,814,870
# Audi R8 Spyder 5.2 V10 performance RWD  23,769,000
# Audi R8 Spyder  23,769,000
# Audi R8 Spyder Convertible  23,769,000
# Audi R8 Spyder Coupe  22,502,710
# Audi R8 V10 Performance  22,266,410
# BMW XM  22,101,000
# Audi R8 Coupe 5.2 V10 performance RWD  22,045,400
# Audi R8 Coupe V10  22,045,400
# BMW Alpina B5 GT Sedan  21,807,710
# BMW M5 CS  21,128,000
# BMW M5 CS Sedan  20,711,000
# BMW Alpina XB7 xDrive  20,155,000
# BMW Alpina B8 Gran Coupe  20,141,100
# BMW Alpina B8 xDrive Gran Coupe  20,141,100

# %%
# Printing the dataset from the first link
df = pd.read_csv('cars_prices.csv')
df.head()
# Out:
#                                    name          price
# 0                    Audi S1 Hoonitron   1,059,736,000
# 1                  Bugatti W16 Mistral     695,000,000
# 2  Bugatti Chiron Super Sport 300 Plus     542,100,000
# 3            Lamborghini Sian Roadster     542,100,000
# 4           Bugatti Chiron Super Sport     535,150,000

# %%
# Inserting a new column for the year
df.insert(1, "year", [2023]*len(df))
df.head()
# Out:
#                                    name  year          price
# 0                    Audi S1 Hoonitron   2023  1,059,736,000
# 1                  Bugatti W16 Mistral   2023    695,000,000
# 2  Bugatti Chiron Super Sport 300 Plus   2023    542,100,000
# 3            Lamborghini Sian Roadster   2023    542,100,000
# 4           Bugatti Chiron Super Sport   2023    535,150,000

# %%
# Checking the number of rows and columns
df.shape
# Out:
# (72, 3)

# %% [markdown]
# #### 2. b. Accessing the website, extracting data, importing to csv file (Second Link)

# %%
source = requests.get('https://www.ccarprice.com/ke/2022-model-car-price-in-Kenya-70.php') # requesting access

soup = BeautifulSoup(source.text,'html.parser') # pearsing the html page

# creating csv file
with open('cars_prices2.csv', 'w', newline='', encoding='utf-8') as f:
    thewriter = writer(f)
    header = ['name', 'price']
    thewriter.writerow(header)
    
    cars = soup.find_all('div', class_='listing') # finding all the div tag which has a class named listing
    
    # looping through all the div tags with a class named listing, and extracting needed cars' details
    for car in cars:
        name = car.strong.text.strip('[]')[:-4] # extracting the text without the date and any square bracket
        price = car.text.split()[-1] # extracting the text without first string
        print(name, price)
        
        # setting columns' names
        carsinfo = [name, price]
        thewriter.writerow(carsinfo)
# Out:
# Bugatti Divo  792,300,000
# Bugatti W16 Mistral  690,604,820
# Bugatti Chiron Super Sport 300 Plus  542,100,000
# Bugatti Chiron Super Sport  535,150,000
# Lamborghini Sian Roadster  514,300,000
# Hennessey Venom F5 Roadster  417,000,000
# Hennessey Venom F5  389,200,000
# Rimac Nevera  333,600,000
# Ferrari Daytona SP3  312,750,000
# Mclaren Elva  275,220,000
# Lamborghini Aventador SVJ Roadster  114,801,490
# Rolls Royce Phantom  64,635,000
# Rolls Royce Dawn  59,498,950
# Mclaren 765LT Spider  52,542,000
# Rolls Royce Cullinan  48,650,000
# Rolls Royce Ghost  47,329,500
# Ferrari 296 GTB  44,674,600
# Bentley Continental GT Speed Convertible  42,033,600
# Bentley Continental GT Speed  38,211,100
# Lamborghini Huracan Evo  36,317,086
# Tesla Roadster 720 MJ  34,750,000
# Lamborghini Huracan Tecnica  33,221,000
# Bentley Bentayga  30,552,200
# Lamborghini Urus  30,302,000
# Aston Martin DB11 V8 Coupe  28,578,400
# Bentley Flying Spur Hybrid  28,356,000
# Tesla Roadster 720 MJ Convertible  28,008,500
# Porsche Cayenne E-Hybrid Coupe  23,324,200
# Bentley Bentayga Hybrid  22,240,000
# Porsche Cayenne Turbo Coupe  18,556,500
# Tesla Model S Plaid  18,068,610
# Porsche Cayenne Turbo  18,056,100
# Tesla Model X Plaid  16,678,610
# Jaguar F-Type R Convertible  14,720,100
# Tesla Model X Performance  14,593,610
# Tesla Model S  14,593,610
# Jeep Grand Wagoneer  13,900,000
# Jeep Grand Cherokee Trackhawk  12,519,730
# Lincoln Navigator L Reserve  12,119,410
# VinFast VF9  11,676,000
# Porsche Cayenne E-Hybrid  11,578,700
# Jaguar F-Type Convertible  11,537,000
# Dodge Durango SRT Hellcat  11,481,400
# Jaguar F-Type R Coupe  11,106,100
# Audi RS5 Sportback  10,591,800
# Audi RS5 Coupe  10,550,100
# Ram 1500 TRX  10,519,520
# Genesis G90  10,279,050
# Rivian R1T Truck Adventure  10,147,000
# Ford Mustang Shelby GT500  10,071,940
# Jeep Grand Cherokee SRT  10,048,310
# Infiniti QX80  10,001,050
# Audi RS3  8,340,000
# Audi RS3 2.5T Quattro  8,199,610
# GMC Yukon XL SLE 4WD  8,034,200
# Acura TLX  7,450,400
# Genesis GV80 2.5T  6,977,800
# Volkswagen ID.4  6,802,660
# MINI John Cooper Works GP Hardtop  6,797,100
# Volvo S60 Recharge  6,623,350
# Infiniti QX60  6,512,150
# Infiniti QX55  6,463,500
# Jaguar XF P250 S  6,296,700
# Buick Enclave  6,227,200
# Volkswagen Golf R  6,065,960
# Ram ProMaster Window Van 3500  5,975,610
# VinFast VF8  5,699,000
# Audi A4 Sedan  5,546,100
# KIA Stinger GT-Line  5,466,870
# Acura RDX  5,462,700
# Subaru WRX STI  5,391,810
# Volkswagen Jetta GLI 2.0T  5,365,400

# %%
# Printing the dataset from the second link
df2 = pd.read_csv('cars_prices2.csv')
df2.head()
# Out:
#                                    name        price
# 0                         Bugatti Divo   792,300,000
# 1                  Bugatti W16 Mistral   690,604,820
# 2  Bugatti Chiron Super Sport 300 Plus   542,100,000
# 3           Bugatti Chiron Super Sport   535,150,000
# 4            Lamborghini Sian Roadster   514,300,000

# %%
# Inserting a new column for the year
df2.insert(1, "year", [2022]*len(df2))
df2.head()
# Out:
#                                    name  year        price
# 0                         Bugatti Divo   2022  792,300,000
# 1                  Bugatti W16 Mistral   2022  690,604,820
# 2  Bugatti Chiron Super Sport 300 Plus   2022  542,100,000
# 3           Bugatti Chiron Super Sport   2022  535,150,000
# 4            Lamborghini Sian Roadster   2022  514,300,000

# %%
# Checking the number of rows and columns
df2.shape
# Out:
# (72, 3)

# %% [markdown]
# #### 2. c. Accessing the website, extracting data, importing to csv file (Third Link)

# %%
source = requests.get('https://www.ccarprice.com/ke/2021-model-car-price-in-Kenya-53.php') # requesting access

soup = BeautifulSoup(source.text,'html.parser') # pearsing the html page

# creating csv file
with open('cars_prices3.csv', 'w', newline='', encoding='utf-8') as f:
    thewriter = writer(f)
    header = ['name', 'price']
    thewriter.writerow(header)
    
    cars = soup.find_all('div', class_='listing') # finding all the div tag which has a class named listing
    
    # looping through all the div tags with a class named listing, and extracting needed cars' details
    for car in cars:
        name = car.strong.text.strip('[]')[:-4] # extracting the text without the date and any square bracket
        price = car.text.split()[-1] # extracting the text without first string
        print(name, price)
        
        # setting columns' names
        carsinfo = [name, price]
        thewriter.writerow(carsinfo)
# Out:
# Lamborghini Sian Roadster  514,300,000
# Bugatti Chiron Pur Sport  493,450,000
# Mclaren Sabre  486,500,000
# Lamborghini Sian Roadster Hybrid  458,370,570
# Mclaren Elva  254,370,000
# Rolls Royce Phantom  67,797,250
# Lamborghini Aventador SVR Track-Only Edition  62,550,000
# Rolls Royce Dawn  49,553,500
# Rolls Royce Cullinan  45,870,000
# Rolls Royce Ghost  43,354,100
# Lamborghini Urus Performante  30,302,000
# Lamborghini Urus  30,302,000
# Lamborghini Huracan Evo  28,991,230
# Bentley Bentayga  24,603,000
# Bentley Bentayga Hybrid  22,240,000
# Porsche Cayenne Turbo  17,583,500
# Bollinger B2  17,375,000
# Tesla Model X Plaid  16,678,610
# Tesla Model S Plaid  16,678,610
# Jaguar F-Type R Convertible  14,720,100
# Jaguar F-Type R Coupe  14,344,800
# Tesla Model X Performance  13,898,610
# Tesla Model S Performance  12,786,610
# Lincoln Navigator L Reserve 4x4  12,212,540
# Porsche Cayenne E-Hybrid  11,370,200
# Dodge Durango SRT Hellcat  11,257,610
# Audi RS5 Sportback  10,480,600
# Audi RS5 Coupe  10,438,900
# Ford Mustang Shelby GT500  9,771,700
# Jeep Grand Cherokee SRT  9,613,240
# Rivian R1T Truck  9,591,000
# Jaguar F-Type Convertible  8,993,300
# GMC Yukon XL SLE 2WD  7,422,600
# Genesis GV80 2.5T  6,797,100
# MINI John Cooper Works GP  6,241,100
# Jaguar XF P250 S  6,114,610
# GMC Sierra 3500HD  5,184,700
# Subaru WRX STI  5,176,360
# Honda Ridgeline Sport  5,072,110
# Subaru Crosstrek Hybrid  4,912,260
# KIA Stinger GT-Line AWD  4,905,310
# Acura TLX  4,865,000
# Hyundai Veloster N  4,482,750
# KIA Telluride LX FWD  4,446,610
# Volkswagen Atlas Cross Sport 2.0T S  4,288,150
# Volkswagen Golf GTI 2.0T  3,974,010
# Volkswagen Golf GTI 2.0T DSG  3,974,010
# Subaru WRX Sedan  3,821,110
# Buick Encore  3,224,800
# Chevrolet Trax LS  2,974,600

# %%
# Printing the dataset from the third link
df3 = pd.read_csv('cars_prices3.csv')
df3.head()
# Out:
#                                 name        price
# 0         Lamborghini Sian Roadster   514,300,000
# 1          Bugatti Chiron Pur Sport   493,450,000
# 2                     Mclaren Sabre   486,500,000
# 3  Lamborghini Sian Roadster Hybrid   458,370,570
# 4                      Mclaren Elva   254,370,000

# %%
# Inserting a new column for the year
df3.insert(1, "year", [2021]*len(df3))
df3.head()
# Out:
#                                 name  year        price
# 0         Lamborghini Sian Roadster   2021  514,300,000
# 1          Bugatti Chiron Pur Sport   2021  493,450,000
# 2                     Mclaren Sabre   2021  486,500,000
# 3  Lamborghini Sian Roadster Hybrid   2021  458,370,570
# 4                      Mclaren Elva   2021  254,370,000

# %%
# Checking the number of rows and columns
df3.shape
# Out:
# (50, 3)

# %% [markdown]
# #### 2. d. Accessing the website, extracting data, importing to csv file (First Link)

# %%
source = requests.get('https://www.ccarprice.com/ke/2020-model-car-price-in-Kenya-51.php') # requesting access

soup = BeautifulSoup(source.text,'html.parser') # pearsing the html page

# creating csv file
with open('cars_prices4.csv', 'w', newline='', encoding='utf-8') as f:
    thewriter = writer(f)
    header = ['name', 'price']
    thewriter.writerow(header)
    
    cars = soup.find_all('div', class_='listing') # finding all the div tag which has a class named listing
    
    # looping through all the div tags with a class named listing, and extracting needed cars' details
    for car in cars:
        name = car.strong.text.strip('[]')[:-4] # extracting the text without the date and any square bracket
        price = car.text.split()[-1] # extracting the text without first string
        print(name, price)
        
        # setting columns' names
        carsinfo = [name, price]
        thewriter.writerow(carsinfo)
# Out:
# Bugatti Divo  806,200,000
# Bugatti Chiron Super Sport 300 Plus  542,100,000
# Lamborghini Sian  514,300,000
# Mclaren Speedtail  309,970,000
# Lamborghini Aventador SVJ Roadster  79,780,440
# Lamborghini Aventador SVJ 2 71,585,000
# Lamborghini Aventador S Roadster  64,974,160
# Rolls Royce Wraith  63,909,420
# Rolls Royce Phantom  63,245,000
# Rolls Royce Cullinan  53,278,700
# Rolls Royce Dawn  48,135,700
# Rolls Royce Wraith  44,549,500
# Rolls Royce Ghost  43,785,000
# Lamborghini Huracan Evo Spyder RWD  39,948,600
# Lamborghini Huracan EVO  36,316,530
# Bentley Continental GT V8 First Edition  34,786,140
# Lamborghini Huracan Evo Spyder  34,388,600
# Bentley Continental GT V8 Convertible  30,955,300
# Lamborghini Urus  28,354,610
# Bentley Bentayga  23,393,700
# Bentley Bentayga Hybrid  22,240,000
# Porsche Cayenne Turbo Coupe AWD  18,083,900
# Tesla Model X Performance  14,593,610
# Tesla Model S Performance  13,898,610
# Audi RS5 Sportback  12,871,400
# Audi RS5 Coupe  12,857,500
# Lincoln Navigator L Reserve 4x4  12,124,970
# Porsche Cayenne E-Hybrid Coupe  12,009,600
# Ford Mustang Shelby GT500 Fastback  9,771,700
# Dodge Charger SRT Hellcat  9,679,960
# Jaguar XF Sportbrake Prestige AWD  9,048,900
# Ford Mustang Shelby GT350 Fastback  8,220,460
# Jaguar XF Sedan 25t Prestige AWD  8,131,500
# Toyota GR Supra  7,809,020
# BMW 2 Series Gran Coupe  5,282,000
# Acura RDX  5,226,400
# Subaru WRX STI  5,141,610
# Lexus UX Hybrid 250h F SPORT  5,073,500
# KIA Stinger GT-Line AWD  4,905,310
# Subaru Crosstrek Hybrid  4,884,460
# Lexus UX Hybrid 250h  4,795,500
# KIA Telluride LX AWD  4,670,400
# Volkswagen Atlas Cross Sport 2.0T S  4,245,060
# Fiat 124 Spider Abarth Convertible  4,072,700
# Hyundai Veloster N  3,836,400
# Volkswagen Tiguan 2.0T S  3,461,100
# Subaru Legacy  3,160,860
# Subaru Crosstrek  3,077,460
# Fiat 500L Pop Hatch  3,056,610
# Chevrolet Trax LS  2,960,700

# %%
# Printing the dataset from the fourth link
df4 = pd.read_csv('cars_prices4.csv')
df4.head()
# Out:
#                                    name        price
# 0                         Bugatti Divo   806,200,000
# 1  Bugatti Chiron Super Sport 300 Plus   542,100,000
# 2                     Lamborghini Sian   514,300,000
# 3                    Mclaren Speedtail   309,970,000
# 4   Lamborghini Aventador SVJ Roadster    79,780,440

# %%
# Inserting a new column for the year
df4.insert(1, "year", [2020]*len(df4))
df4.head()
# Out:
#                                    name  year        price
# 0                         Bugatti Divo   2020  806,200,000
# 1  Bugatti Chiron Super Sport 300 Plus   2020  542,100,000
# 2                     Lamborghini Sian   2020  514,300,000
# 3                    Mclaren Speedtail   2020  309,970,000
# 4   Lamborghini Aventador SVJ Roadster   2020   79,780,440

# %%
# Checking the number of rows and columns
df4.shape
# Out:
# (50, 3)

# %%
# Merging all datasets into a single dataset
my_df = pd.concat([df, df2, df3, df4], ignore_index=True)
my_df
# Out:
#                                      name  year          price
# 0                      Audi S1 Hoonitron   2023  1,059,736,000
# 1                    Bugatti W16 Mistral   2023    695,000,000
# 2    Bugatti Chiron Super Sport 300 Plus   2023    542,100,000
# 3              Lamborghini Sian Roadster   2023    542,100,000
# 4             Bugatti Chiron Super Sport   2023    535,150,000
# ..                                    ...   ...            ...
# 239             Volkswagen Tiguan 2.0T S   2020      3,461,100
# 240                        Subaru Legacy   2020      3,160,860
# 241                     Subaru Crosstrek   2020      3,077,460
# 242                  Fiat 500L Pop Hatch   2020      3,056,610
# 243                    Chevrolet Trax LS   2020      2,960,700
#
# [244 rows x 3 columns]

# %%
# Checking the number of rows and columns
my_df.shape
# Out:
# (244, 3)
